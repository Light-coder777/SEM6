# %% [markdown]
# ### Sarvayga Singh
# #### 60009200030 - K1
# #### IPCV - lab6
# #### Contrast Stretching

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/imager.jpeg',0)
img
# Out:
# array([[206, 206, 206, ..., 207, 207, 207],
#        [206, 206, 206, ..., 207, 207, 207],
#        [206, 206, 206, ..., 207, 207, 207],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
np.shape(img)
# Out:
# (280, 600)

# %%
final_img = [[0 for j in range(np.shape(img)[1])] for i in range(np.shape(img)[0])]
np.shape(final_img)
# Out:
# (280, 600)

# %%
image = cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=600x280 at 0x7F8062FED9D0>

# %%
rmax,rmin = np.max(img),np.min(img)
rX = (rmax , rmin)
rX
# Out:
# (255, 31)

# %%
smax,smin = 255,0
sX = (smax , smin)
sX
# Out:
# (255, 0)

# %%
ratio = (sX[0]-sX[1])/(rX[0]-rX[1])
ratio
# Out:
# 1.1383928571428572

# %%
imgX = np.reshape(img,-1)
imgX
# Out:
# array([206, 206, 206, ..., 255, 255, 255], dtype=uint8)

# %%
plt.figure(figsize=(10,7))    	        
plt.hist(imgX, bins=256);

# %%
for i,lister in enumerate(img):
  for j,value in enumerate(lister):
    final_img[i][j] = ratio*(value-rmin) + smin

final_img = np.array(final_img)

# %%
np.shape(final_img)
# Out:
# (280, 600)

# %%
final_imgX = np.reshape(final_img,-1)
final_imgX
# Out:
# array([199.21875, 199.21875, 199.21875, ..., 255.     , 255.     ,
#        255.     ])

# %%
cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=600x280 at 0x7F8092F28C70>

# %%
plt.figure(figsize=(10,7))
plt.hist(final_imgX, bins=256);

# %%
np.max(final_imgX),np.min(final_imgX)
# Out:
# (255.0, 0.0)

# %%
# !jupyter nbconvert --to html '/content/IPCV_lab6.ipynb'
# Out:
# [NbConvertApp] Converting notebook /content/IPCV_lab6.ipynb to html
# [NbConvertApp] Writing 735287 bytes to /content/IPCV_lab6.html
